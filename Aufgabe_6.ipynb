# %%
cd /tmp
rm -rf terminal_course
ls
# Out:
# snap-private-tmp
# systemd-private-04b2c8b741e64a368b7c87a63c26c364-systemd-logind.service-mzgfY6
# systemd-private-04b2c8b741e64a368b7c87a63c26c364-systemd-resolved.service-1yUu3Z
# systemd-private-04b2c8b741e64a368b7c87a63c26c364-systemd-timesyncd.service-Wnfo2Y
# systemd-private-04b2c8b741e64a368b7c87a63c26c364-wsl-pro.service-NC44c5

# %%
mkdir terminal_course
cd terminal_course
ls

# %%
cp -r '/mnt/c/Users/z004z5nm/OneDrive - Siemens Healthineers/Programming/TerminalCourse/data' .
cp '/mnt/c/Users/z004z5nm/OneDrive - Siemens Healthineers/Programming/TerminalCourse/dir_tree_gen' .
ls
# Out:
# data  dir_tree_gen

# %%
ls -lh
# Out:
# total 8.0K
# drwxr-xr-x 2 thetruealchemist thetruealchemist 4.0K Dec 18 10:33 data
# -rwxr-xr-x 1 thetruealchemist thetruealchemist  882 Dec 18 10:33 dir_tree_gen

# %%
python3 dir_tree_gen
ls
# Out:
# data  dir_tree_gen  topdir

# %%
cd topdir

# %%
find . -type d | wc -l
# Out:
# 3907

# %%
find . -type f -name '*.txt' | wc -l
# Out:
# 7812

# %%
find . -type f -name '*.txt' | xargs cat | grep -o 'love' | wc -l
# Out:
# 1278

# %%
find . -type f -name '*.txt' | xargs cat | grep 'love'
# Out:
# Both truth and beauty on my love depends:
# Nor my beloved as an idol show,
# Let not my love be called idolatry,
# Kind is my love to-day, to-morrow kind,
# My love looks fresh, and death to me subscribes,
# Can yet the lease of my true love control,
# That may express my love, or thy dear merit?
# My love is strengthened though more weak in seeming,
# I love not less, though less the show appear,
# Our love was new, and then but in the spring,
# That love is merchandized, whose rich esteeming,
# In praise of ladies dead, and lovely knights,
# Like a deceived husband, so love's face,
# May still seem love to me, though altered new:
# Happy to have thy love, happy to die!
# That in thy face sweet love should ever dwell,
# For it depends upon that love of thine.
# And life no longer than thy love will stay,
# Thy love is better than high birth to me,
# Such is my love, to thee I so belong,
# Thou canst not (love) disgrace me half so ill,
# ...
